# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import perturbate


image_path = "data/less-autistic-2.jpg"
save_to_dir = "data/perturbations/less"

perturbate.main(
    image_path=image_path,
    kernel_size=3,
    nblocks=3,
    nlayers=3,
    epochs=100,#000,
    lr=0.001,
    l1_coeff=1.0,
    class_index="max",
    init_pert_model=True,
    save_to_dir=save_to_dir,
    datetime_subdir=False,
)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [04:13<00:00,  2.54s/it]
# original score: tensor([0.2026, 0.1330, 0.0862, 0.0447, 0.0365])
# perturbed score: tensor([0.0008, 0.0037, 0.0082, 0.0011, 0.0015], grad_fn=<IndexBackward>)
# original input evaluation:
# 5 top classes identified by the model:
# (class index) class description: model score
# 869 trench coat: 0.20263293385505676
# 652 military uniform: 0.13301175832748413
# 568 fur coat: 0.0861758440732956
# 834 suit, suit of clothes: 0.04473211243748665
# 523 crutch: 0.036488085985183716
# perturbated input evaluation:
# 5 top classes identified by the model:
# (class index) class description: model score
# 433 bathing cap, swimming cap: 0.39476990699768066
# 796 ski mask: 0.07110545784235
# 898 water bottle: 0.04952680692076683
# 773 saltshaker, salt shaker: 0.042197711765766144
# ...
